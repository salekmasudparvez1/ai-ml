# %%
import kagglehub
import os
import pandas as pd

# Download latest version
path = kagglehub.dataset_download("spscientist/students-performance-in-exams")
real_path = os.path.join(path,os.listdir(path)[0])
read_csv = pd.read_csv(real_path)
# print(read_csv.columns)
print(read_csv.loc[:,"gender"])
print(read_csv.iloc[:,"gender"])
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
import numpy as np
a = [[1,2,3,4],[5,6,7,8]]
new_shape = (4, 2)
print(new_shape[0])
# Out:
# 4
