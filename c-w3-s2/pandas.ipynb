# %%
import kagglehub
import pandas as pd
import os

# Download dataset
path = kagglehub.dataset_download("spscientist/students-performance-in-exams")

print("Dataset folder:", path)
print("Files:", os.listdir(path))

# # Load the CSV file
# csv_path = os.path.join(path, "StudentsPerformance.csv")   # likely filename
# df = pd.read_csv(csv_path)

# print(df.head())
# Out:
# Dataset folder: /home/salekmasudparvez/.cache/kagglehub/datasets/spscientist/students-performance-in-exams/versions/1
# Files: ['StudentsPerformance.csv']
