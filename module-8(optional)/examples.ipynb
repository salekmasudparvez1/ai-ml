# %%
import pandas as pd
import numpy as np



np.set_printoptions(suppress=True)
chunks = pd.read_csv("student_study_dataset.csv")
data = chunks.to_numpy(dtype=np.float64)
# Out:
# 200

# %%
# create a array like (1,) of random index of data 
random_index = np.random.choice(len(data), size=(len(data),),replace=False)
ramdon_data = data[random_index]
# features
x = ramdon_data[:,1:3]
# target
y = ramdon_data[:,3]
# print(x)
# print(y)
# print(x.shape)
# print(y.shape)
# Out:
# (200,)

# %%
# train data
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

train_index =int(len(data)*0.8)


x_train_cus = x[:train_index,]
y_train_cus = y[:train_index,]

# print("train_index =",train_index)
# print("train data length =",len(x_train))


x_test_cus =x[train_index:,]
y_test_cua =y[train_index:,]

# print("test data length =",len(x_test))

# X_train, X_test, y_train, y_test = train_test_split(
#     x, y, test_size=0.2,
# )

# 4. Train model
model = LinearRegression()
model.fit(x_train_cus, y_train_cus)

# 5. Test model
accuracy = model.score(x_train_cus, y_train_cus)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9801368693180381
