# %%
import pandas as pd
df = pd.DataFrame({
 "Gender":["Male","Female","Male","Male"]   
})
df.head()
# Out:
#   Cell In[7], line 1
#     import pandas pd
#                   ^
# SyntaxError: invalid syntax
