# %%
import pandas as pd
df = pd.DataFrame({
 "Gender":["Male","Female","Male","Male"]   
})
df['Gender']=df["Gender"].map({
    "Male":10,
    "Female":11
})
df
# Out:
#    Gender
# 0      10
# 1      11
# 2      10
# 3      10
