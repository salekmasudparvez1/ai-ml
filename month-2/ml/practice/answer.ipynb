# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("DOHMH_New_York_City_Restaurant_Inspection_Results.csv")
df.sample(10)
# Out:
#            CAMIS                              DBA       BORO BUILDING  \
# 232550  41699493                STOP & GO CHICKEN     QUEENS   120-36
# 215136  41292268                           T BAAR   BROOKLYN     4823
# 251379  41693243                    SOLE DI CAPRI  MANHATTAN      165
# 322849  50001074                           SUBWAY     QUEENS    56-53
# 294688  41589254          POTBELLY SANDWICH WORKS  MANHATTAN      150
# 360488  50001089                           BLANCA   BROOKLYN      261
# 42443   50006420                    TACOS TIJUANA   BROOKLYN     5807
# 220884  50057067  PEPPA'S JERK CHICKEN RESTAURANT   BROOKLYN      689
# 141009  40799056            ABIGAEL'S ON BROADWAY  MANHATTAN     1407
# 311479  41350705                        STARBUCKS  MANHATTAN     1740
#
#                   STREET  ZIPCODE       PHONE             CUISINE DESCRIPTION  \
# 232550  QUEENS BOULEVARD  11415.0  7182610001                         Chicken
# 215136          8 AVENUE  11220.0  3473503522  Juice, Smoothies, Fruit Salads
# 251379     CHURCH STREET  10007.0  2125131113                         Italian
# 322849        MYRTLE AVE  11385.0  7184175495                      Sandwiches
# 294688  EAST   44 STREET  10017.0  6462894202                        American
# 360488             MOORE  11206.0  7184171118                     Continental
# 42443            5TH AVE  11220.0  7184924369                         Mexican
# 220884         UTICA AVE  11203.0  3473833127                       Caribbean
# 141009          BROADWAY  10018.0  2125751407                   Jewish/Kosher
# 311479          BROADWAY  10019.0  2129048817                        American
#
#        INSPECTION DATE                                             ACTION  \
# 232550      07/23/2014    Violations were cited in the following area(s).
# 215136      09/18/2014  Establishment Closed by DOHMH.  Violations wer...
# 251379      11/05/2014    Violations were cited in the following area(s).
# 322849      07/17/2014    Violations were cited in the following area(s).
# 294688      08/20/2015    Violations were cited in the following area(s).
# 360488      07/20/2017    Violations were cited in the following area(s).
# 42443       08/17/2015    Violations were cited in the following area(s).
# 220884      03/30/2017    Violations were cited in the following area(s).
# 141009      04/13/2015    Violations were cited in the following area(s).
# 311479      04/16/2015    Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 232550            15L  Smoke free workplace smoking policy inadequate...
# 215136            04N  Filth flies or food/refuse/sewage-associated (...
# 251379            16B  The original nutritional fact labels and/or in...
# 322849            04N  Filth flies or food/refuse/sewage-associated (...
# 294688            10F  Non-food contact surface improperly constructe...
# 360488            02B        Hot food item not held at or above 140Âº F.
# 42443             08A  Facility not vermin proof. Harborage or condit...
# 220884            08A  Facility not vermin proof. Harborage or condit...
# 141009            10F  Non-food contact surface improperly constructe...
# 311479            10F  Non-food contact surface improperly constructe...
#
#        CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 232550  Not Critical    NaN   NaN         NaN  08/28/2017
# 215136      Critical   96.0   NaN         NaN  08/28/2017
# 251379  Not Critical    NaN   NaN         NaN  08/28/2017
# 322849      Critical   19.0   NaN         NaN  08/28/2017
# 294688  Not Critical   27.0   NaN         NaN  08/28/2017
# 360488      Critical   12.0     A  07/20/2017  08/28/2017
# 42443   Not Critical   24.0   NaN         NaN  08/28/2017
# 220884  Not Critical   32.0   NaN         NaN  08/28/2017
# 141009  Not Critical    8.0     A  04/13/2015  08/28/2017
# 311479  Not Critical    7.0     A  04/16/2015  08/28/2017
#
#                                       INSPECTION TYPE
# 232550        Smoke-Free Air Act / Initial Inspection
# 215136          Cycle Inspection / Initial Inspection
# 251379              Trans Fat / Compliance Inspection
# 322849          Cycle Inspection / Initial Inspection
# 294688          Cycle Inspection / Initial Inspection
# 360488          Cycle Inspection / Initial Inspection
# 42443           Cycle Inspection / Initial Inspection
# 220884  Pre-permit (Operational) / Initial Inspection
# 141009               Cycle Inspection / Re-inspection
# 311479          Cycle Inspection / Initial Inspection

# %%
df.isnull().sum()
# Out:
# CAMIS                         0
# DBA                         359
# BORO                          0
# BUILDING                    109
# STREET                        9
# ZIPCODE                       9
# PHONE                         5
# CUISINE DESCRIPTION           0
# INSPECTION DATE               0
# ACTION                     1135
# VIOLATION CODE             6504
# VIOLATION DESCRIPTION      6979
# CRITICAL FLAG                 0
# SCORE                     23214
# GRADE                    204505
# GRADE DATE               207098
# RECORD DATE                   0
# INSPECTION TYPE            1135
# dtype: int64

# %% [markdown]
# 1. Handle missing values in `SCORE`, `GRADE`, and `VIOLATION CODE`.
