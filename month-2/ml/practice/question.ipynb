# %% [markdown]
# ---
#
# ### 🧠 Question:
#
# **Using a random sample of restaurant inspection scores from a public health dataset, analyze the relationship between inspection score, violation type, and inspection year. Apply at least two multivariate visualizations and generate an automated profiling report.**
#
# ---
#
# ## ✅ Dataset Suggestion:
#
# **`Restaurant Inspection Scores`** (from NYC Open Data or similar)
#
# - Can be accessed via Kaggle: [NYC Restaurant Inspection Results](https://www.kaggle.com/datasets/new-york-city/nyc-restaurant-inspection-results)
# - **Columns**: `CAMIS`, `DBA`, `BORO`, `CUISINE DESCRIPTION`, `INSPECTION DATE`, `SCORE`, `GRADE`, `VIOLATION CODE`, `CRITICAL FLAG`, `INSPECTION TYPE`
#
# ---
#
# ## 📌 Tasks (based on what you’ve learned):
#
# 1. **Load and clean the data**
#    - Handle missing values in `SCORE`, `GRADE`, and `VIOLATION CODE`.
#
# 2. **Univariate analysis**
#    - Plot distribution of `SCORE` and `GRADE`.
#
# 3. **Bivariate/Multivariate analysis**
#    - Create a **countplot** showing `GRADE` by `BORO` (borough).
#    - Create a **barplot** showing mean `SCORE` by `CRITICAL FLAG`.
#    - Create a **KDE plot** of `SCORE` grouped by `INSPECTION YEAR`.
#    - Create a **scatterplot** of `SCORE` vs. `INSPECTION YEAR`, colored by `CRITICAL FLAG`.
#
# 4. **Generate a YData profiling report**
#    - Automatically detect data types, correlations, missing patterns, and alerts.
#
# 5. **Interpretation**
#    - Write a short paragraph explaining which factors most strongly correlate with low inspection scores.
#
# ---
#
# ## 🎯 Why this question is good for your learning level:
#
# | Your Skill                | How This Question Reinforces It                      |
# | ------------------------- | ---------------------------------------------------- |
# | Multivariate plotting     | Use of `hue`, `size`, and `col` in `seaborn`         |
# | Data profiling            | `ydata-profiling` on a new dataset                   |
# | Real-world data wrangling | Missing values, date parsing, categorical mapping    |
# | Critical thinking         | Identifying which violations or cuisines are riskier |
#
# ---

# %%
#!/bin/bash
# !kaggle datasets download new-york-city/nyc-inspections
# Out:
# Dataset URL: https://www.kaggle.com/datasets/new-york-city/nyc-inspections
# License(s): CC0-1.0
# ...
# 100%|██████████████████████████████████████| 21.5M/21.5M [00:04<00:00, 4.70MB/s]
